# %%
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

# %% [markdown]
# # FEATURE IMPORTANCE

# %%
df = pd.read_csv("/content/sample_data/mnist_test.csv")

# %%
# can do using random forest , ensbmle , deccision tree , boosting , any tree based algo

# %%
y = df['7']
x= df.drop(columns=['7'])

# %%
x_train , x_test , y_train , y_test = train_test_split(x,y,test_size =0.3 , stratify = y  , random_state =12)

# %%
bag = RandomForestClassifier()
bag.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
imp =(bag.feature_importances_).reshape(28,28)

# %%
import seaborn as sns

# %%
sns.heatmap(imp)
# Out:
# <Axes: >

# %%
from sklearn.inspection import permutation_importance as pi
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import GridSearchCV , learning_curve ,RandomizedSearchCV

# %%
knn = KNeighborsClassifier(p=1)
knn.fit(x_train , y_train)
from sklearn.inspection import permutation_importance

# %%
result = permutation_importance(
    estimator=knn,      # Your trained model (e.g., KNeighborsClassifier)
    X=x_train,          # Training data
    y=y_train,          # Labels
    scoring="accuracy", # Scoring metric
    n_repeats=10,       # How many times to permute each feature
    random_state=42     # For reproducibility (optional but recommended)
)
