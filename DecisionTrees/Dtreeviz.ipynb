# %% [markdown]
# from dtree.viz import model as dtreeviz_model
#
# viz = dtreeviz(model_object , x_train.to_numpy , y_train.to _numpy,
#                 feature_names = x_train.columns.to_list() , class_names = y_train.value_counts().to_list(),
#                 target_name = target_col_name
#
#
# )
#
# viz.view(params)
# params = just_view_path = True , orientation = 'LR'  ,  scale = 1.2
#
#       fancy = False  , x = test_point ,
#
#  view: show_just_paths , fancy , orientation , show_node_labels
#  view: orientation , show_just_paths , show_node_labels

# %%
# 📦 Imports
import pandas as pd
from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, classification_report
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns


# 📊 1. Generate synthetic dataset
X, y = make_classification(
    n_samples=500,     # number of rows
    n_features=8,      # number of features
    n_informative=5,   # useful features
    n_redundant=2,     # redundant features
    n_classes=2,       # binary classification
    random_state=42
)

# 🧱 2. Convert to pandas DataFrame
df = pd.DataFrame(X, columns=[f'feature_{i}' for i in range(X.shape[1])])
df['target'] = y

# 🔪 3. Split into train/test sets
X_train, X_test, y_train, y_test = train_test_split(
    df.drop(columns='target'),
    df['target'],
    test_size=0.3,
    random_state=42,
    stratify=df['target']
)

# 🌳 4. Train Decision Tree
cls = DecisionTreeClassifier(max_depth=5, random_state=42)
cls.fit(X_train, y_train)

# 🎯 5. Evaluate
y_pred = cls.predict(X_test)
acc = accuracy_score(y_test, y_pred)

print("Accuracy:", acc)
print("\nClassification Report:\n", classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.84
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.81      0.89      0.85        76
#            1       0.88      0.78      0.83        74
#
#     accuracy                           0.84       150
#    macro avg       0.84      0.84      0.84       150
# weighted avg       0.84      0.84      0.84       150

# %%
from sklearn.tree import plot_tree
from matplotlib.pylab import rcParams
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# rcParams['figure.figsize'] =80,50
# plot_tree(tree)
# plt.show()
# Out:
# ---------------------------------------------------------------------------
# InvalidParameterError                     Traceback (most recent call last)
# /tmp/ipython-input-134-151225346.py in <cell line: 0>()
#       1 rcParams['figure.figsize'] =80,50
# ----> 2 plot_tree(tree)
#       3 plt.show()
#
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/_param_validation.py in wrapper(*args, **kwargs)
#     204             params = {k: v for k, v in params.arguments.items() if k not in to_ignore}
#     205
# --> 206             validate_parameter_constraints(
#     207                 parameter_constraints, params, caller_name=func.__qualname__
#     208             )
#
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/_param_validation.py in validate_parameter_constraints(parameter_constraints, params, caller_name)
#      96                 )
#      97
# ---> 98             raise InvalidParameterError(
# ...

# %%
# !pip install dtreeviz

# %%
import graphviz.backend as ve
from dtreeviz.trees import *
from IPython.display import  Image , display_svg , SVG

# %%
# !pip install dtreeviz

# %%
import dtreeviz
import graphviz.backend as be
from IPython.display import Image , display_svg

from dtreeviz import model as dtreeviz_model

# %%
viz = dtreeviz_model(
   cls,                             # trained model (cls must be fitted)
    X_train.to_numpy(),                          # features as numpy array
    y_train.to_numpy(),                          # labels as numpy array
    feature_names=df.columns[:-1].tolist(),        # feature names
    class_names=["0", "1"],                        # string class labels
    target_name="target",                          # label for target
                                       # optional: size of plot
)

viz.view()  # or viz.show_in_notebook() in Jupyter
# Out:
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# ...

# %%
# Sample a single row, get features as 1D array
# exclude target column, get 1D feature vector

# Create dtreeviz visualization
viz = dtreeviz_model(
    cls,
    X_train.to_numpy(),
    y_train.to_numpy(),
    feature_names=df.columns[:-1].tolist(),
    target_name="target",
    class_names=["0", "1"],
     # this is a parameter, not an attribute of an object
)

viz.view()  # to display the visualization
# Out:
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# ...

# %%
sample_row = df.sample(1).to_numpy()
x = sample_row[0, :-1]

# %%
viz.view(orientation='LR')
# Out:
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# ...

# %%
viz.view(fancy=False)
# Out:
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# ...

# %%
p= X_train.iloc[10]

# %%
viz.view(x=p)
# Out:
# /usr/local/lib/python3.11/dist-packages/dtreeviz/models/shadow_decision_tree.py:335: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# ...

# %%
viz.view(show_node_labels = True)
# Out:
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# ...

# %%
viz.view(x=p , show_just_path  = True)
# Out:
# /usr/local/lib/python3.11/dist-packages/dtreeviz/models/shadow_decision_tree.py:335: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# ...

# %%
import warnings
import logging
import matplotlib

# Suppress all warnings
warnings.filterwarnings("ignore")

# Suppress matplotlib font manager warnings
logging.getLogger('matplotlib.font_manager').setLevel(logging.ERROR)

# %%
viz.view(scale = 1.2)
# Out:
# WARNING:matplotlib.axes._base:Ignoring fixed x limits to fulfill fixed data aspect with adjustable data limits.
# WARNING:matplotlib.axes._base:Ignoring fixed x limits to fulfill fixed data aspect with adjustable data limits.
# WARNING:matplotlib.axes._base:Ignoring fixed x limits to fulfill fixed data aspect with adjustable data limits.
# WARNING:matplotlib.axes._base:Ignoring fixed x limits to fulfill fixed data aspect with adjustable data limits.
# WARNING:matplotlib.axes._base:Ignoring fixed x limits to fulfill fixed data aspect with adjustable data limits.
# WARNING:matplotlib.axes._base:Ignoring fixed x limits to fulfill fixed data aspect with adjustable data limits.
# WARNING:matplotlib.axes._base:Ignoring fixed x limits to fulfill fixed data aspect with adjustable data limits.
# WARNING:matplotlib.axes._base:Ignoring fixed x limits to fulfill fixed data aspect with adjustable data limits.
# ...

# %%
viz.view(histtype='barstacked')
# Out:
# WARNING:matplotlib.axes._base:Ignoring fixed x limits to fulfill fixed data aspect with adjustable data limits.
# WARNING:matplotlib.axes._base:Ignoring fixed x limits to fulfill fixed data aspect with adjustable data limits.
# WARNING:matplotlib.axes._base:Ignoring fixed x limits to fulfill fixed data aspect with adjustable data limits.
# WARNING:matplotlib.axes._base:Ignoring fixed x limits to fulfill fixed data aspect with adjustable data limits.
# WARNING:matplotlib.axes._base:Ignoring fixed x limits to fulfill fixed data aspect with adjustable data limits.
# WARNING:matplotlib.axes._base:Ignoring fixed x limits to fulfill fixed data aspect with adjustable data limits.
# WARNING:matplotlib.axes._base:Ignoring fixed x limits to fulfill fixed data aspect with adjustable data limits.
# WARNING:matplotlib.axes._base:Ignoring fixed x limits to fulfill fixed data aspect with adjustable data limits.
# ...

# %%
from dtreeviz import *

# %% [markdown]
# n
